# %%
from tensorflow import keras

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# %%
model=VGG16()
model.summary()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import numpy as np

# %%
image=load_img('/content/drive/MyDrive/Colab Notebooks/Clock_image/download.webp',target_size=(224,224))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image=np.array(image)

# %%
image.shape
# Out:
# (224, 224, 3)

# %%
image=image.reshape(1,image.shape[0],image.shape[1],image.shape[2])

# %%
image.shape
# Out:
# (1, 224, 224, 3)

# %%
image=preprocess_input(image)

# %%
image
# Out:
# array([[[[ 97.061,  97.221,  92.32 ],
#          [ 95.061,  94.221,  90.32 ],
#          [ 95.061,  94.221,  90.32 ],
#          ...,
#          [133.061, 122.221, 115.32 ],
#          [133.061, 122.221, 115.32 ],
#          [133.061, 122.221, 115.32 ]],
#
#         [[103.061, 103.221,  98.32 ],
#          [100.061, 100.221,  96.32 ],
#          [100.061, 100.221,  96.32 ],
#          ...,
#          [133.061, 122.221, 115.32 ],
#          [133.061, 122.221, 115.32 ],
#          [133.061, 122.221, 115.32 ]],
#
#         [[103.061, 103.221,  98.32 ],
#          [100.061, 100.221,  96.32 ],
#          [100.061, 100.221,  96.32 ],
#          ...,
#          [133.061, 122.221, 115.32 ],
#          [133.061, 122.221, 115.32 ],
#          [133.061, 122.221, 115.32 ]],
#
#         ...,
#
#         [[119.061, 110.221, 105.32 ],
#          [118.061, 109.221, 103.32 ],
#          [118.061, 109.221, 103.32 ],
#          ...,
#          [126.061, 112.221, 103.32 ],
# ...

# %%
pred=model.predict(image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step

# %%
pred
# Out:
# array([[1.65227132e-09, 7.41839612e-09, 2.49192471e-08, 7.70921904e-09,
#         1.00515161e-08, 4.73618975e-08, 1.35374840e-08, 9.56471524e-09,
#         9.25801924e-09, 1.06092235e-09, 1.47270951e-08, 3.92996071e-08,
#         3.96289224e-08, 4.61178047e-08, 5.89047318e-08, 1.01451816e-08,
#         2.20612755e-08, 2.02339105e-08, 5.24381392e-08, 1.61783760e-08,
#         8.03899614e-09, 1.02359657e-07, 2.05845112e-07, 1.97333243e-08,
#         9.65476232e-08, 2.02571560e-08, 2.24339658e-08, 6.33230854e-08,
#         3.94146085e-08, 8.04746403e-09, 7.98307198e-09, 6.87796753e-09,
#         2.31133601e-08, 9.33616651e-09, 1.14844472e-08, 9.06801478e-09,
#         1.22394788e-08, 7.00652292e-09, 8.69456596e-09, 2.11800160e-08,
#         4.80604179e-08, 8.40146441e-09, 1.17186882e-08, 4.12963068e-08,
#         2.95078504e-08, 3.34431993e-09, 5.41337748e-08, 1.94269063e-08,
#         3.55223695e-09, 1.68404437e-08, 5.72328274e-09, 6.25746068e-08,
# ...

# %%
from tensorflow.keras.applications.imagenet_utils import decode_predictions

# %%
op=decode_predictions(pred)

# %%
op
# Out:
# [[('n02708093', 'analog_clock', np.float32(0.5503682)),
#   ('n04548280', 'wall_clock', np.float32(0.4255626)),
#   ('n02794156', 'barometer', np.float32(0.01808471)),
#   ('n04328186', 'stopwatch', np.float32(0.0019377329)),
#   ('n03706229', 'magnetic_compass', np.float32(0.0010093221))]]

# %%
image_1=load_img('/content/drive/MyDrive/Colab Notebooks/Dog_breeds/download (6).jpeg',target_size=(224,224))

# %%
image_1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image_1=np.array(image_1)

# %%
image_1=image_1.reshape(1,image_1.shape[0],image_1.shape[1],image_1.shape[2])

# %%
image_1=preprocess_input(image_1)

# %%
pred_1=model.predict(image_1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step

# %%
from tensorflow.keras.applications.imagenet_utils import decode_predictions

# %%
op_1=decode_predictions(pred_1)

# %%
op_1
# Out:
# [[('n02099601', 'golden_retriever', np.float32(0.8674163)),
#   ('n02099712', 'Labrador_retriever', np.float32(0.015611498)),
#   ('n02111129', 'Leonberg', np.float32(0.013165521)),
#   ('n04254680', 'soccer_ball', np.float32(0.011967799)),
#   ('n02099267', 'flat-coated_retriever', np.float32(0.010182912))]]

# %% [markdown]
# VGG19-ARCHITECTURE

# %%
from tensorflow.keras.applications.vgg19 import VGG19

# %%
model_1=VGG19()
model_1.summary()
# Out:
# ...
# 574710816/574710816 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import numpy as np

# %%
image_2=load_img('/content/drive/MyDrive/Colab Notebooks/Clock_image/download.webp',target_size=(224,224))

# %%
image_2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image_2=np.array(image_2)

# %%
image_2.shape
# Out:
# (224, 224, 3)

# %%
image_2=image_2.reshape(1,image_2.shape[0],image_2.shape[1],image_2.shape[2])

# %%
image_2.shape
# Out:
# (1, 224, 224, 3)

# %%
image_2=preprocess_input(image_2)

# %%
pred_2=model.predict(image_2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step

# %%
pred_2
# Out:
# array([[1.65227132e-09, 7.41839612e-09, 2.49192471e-08, 7.70921904e-09,
#         1.00515161e-08, 4.73618975e-08, 1.35374840e-08, 9.56471524e-09,
#         9.25801924e-09, 1.06092235e-09, 1.47270951e-08, 3.92996071e-08,
#         3.96289224e-08, 4.61178047e-08, 5.89047318e-08, 1.01451816e-08,
#         2.20612755e-08, 2.02339105e-08, 5.24381392e-08, 1.61783760e-08,
#         8.03899614e-09, 1.02359657e-07, 2.05845112e-07, 1.97333243e-08,
#         9.65476232e-08, 2.02571560e-08, 2.24339658e-08, 6.33230854e-08,
#         3.94146085e-08, 8.04746403e-09, 7.98307198e-09, 6.87796753e-09,
#         2.31133601e-08, 9.33616651e-09, 1.14844472e-08, 9.06801478e-09,
#         1.22394788e-08, 7.00652292e-09, 8.69456596e-09, 2.11800160e-08,
#         4.80604179e-08, 8.40146441e-09, 1.17186882e-08, 4.12963068e-08,
#         2.95078504e-08, 3.34431993e-09, 5.41337748e-08, 1.94269063e-08,
#         3.55223695e-09, 1.68404437e-08, 5.72328274e-09, 6.25746068e-08,
# ...

# %%
op_2=decode_predictions(pred_2)

# %%
op_2
# Out:
# [[('n02708093', 'analog_clock', np.float32(0.5503682)),
#   ('n04548280', 'wall_clock', np.float32(0.4255626)),
#   ('n02794156', 'barometer', np.float32(0.01808471)),
#   ('n04328186', 'stopwatch', np.float32(0.0019377329)),
#   ('n03706229', 'magnetic_compass', np.float32(0.0010093221))]]
